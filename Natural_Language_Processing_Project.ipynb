# %%
# %logstop
# %logstart -rtq ~/.logs/nlp.py append
import seaborn as sns
sns.set()

# %%
from static_grader import grader

# %% [markdown]
# # Collins Natural Language Processing (NLP) project

# %% [markdown]
# ## Introduction
#
# The objective of this project is to gain experience with natural language processing and how to use text data to train a machine learning model to make predictions. For the miniproject, we will be working with product review text from Amazon. The reviews are for only products in the "Electronics" category. The objective is to train a model to predict the rating, ranging from 1 to 5 stars.
#
# ## Scoring
#
# For most of the questions, you will be asked to submit the `predict` method of your trained model to the grader. The grader will use the passed `predict` method to evaluate how your model performs on a test set with respect to a reference model. The grader uses the [R<sup>2</sup>-score](https://scikit-learn.org/stable/modules/model_evaluation.html#r2-score) for model evaluation. If your model performs better than the reference solution, then you can score higher than 1.0. For the last question, you will submit the results of an analysis and your passed answer will be compared directly to the reference solution.
#
# ## Downloading and loading the data
#
# The data set is available on Amazon S3 and comes as a compressed file where each line is a JSON object. To load the data set, we will need to use the `gzip` library to open the file and decode each JSON into a Python dictionary. In the end, we have a list of dictionaries, where each dictionary represents an observation.

# %%
# %%bash
# mkdir data
# wget http://dataincubator-wqu.s3.amazonaws.com/mldata/amazon_electronics_reviews_training.json.gz -nc -P ./data
# Out:
# mkdir: cannot create directory ‘data’: File exists
# File ‘./data/amazon_electronics_reviews_training.json.gz’ already there; not retrieving.

# %%
import gzip
import simplejson as json

with gzip.open("data/amazon_electronics_reviews_training.json.gz", "r") as f:                                  
    data = [json.loads(line) for line in f]

# %%
data[:2]
# Out:
# [{'reviewerID': 'A238V1XTSK9NFE',
#   'asin': 'B00004VX3T',
#   'reviewerName': 'Andrew Lynn',
#   'helpful': [2, 2],
#   'reviewText': "I bought this mouse to use with my laptop because I don't like those little touchpads.  I could not be happier.Since it's USB, I can plug it in with the computer already on and expect it to work automatically.  Since it's optical (the new kind, not to be confused with the old Sun optical mice that required a special checkered mouse pad) it works on most surfaces, including my pant legs, my couch, and random tables that I put my laptop down on.  It's also light and durable, features that help with portability.The wheel is surprisingly useful.  In addition to scrolling, it controls zoom and pan in programs like Autocad and 3D Studio Max.  I can no longer bear using either of these programs without it.One complaint - the software included with the Internet navigation features is useless.  Don't bother installing it if you have a newer Windows version that automatically supports wheel mice.  Just plug it in and use it - it's that easy.",
#   'overall': 5.0,
#   'summary': 'Excellent mouse for laptop users',
#   'unixReviewTime': 1007942400,
#   'reviewTime': '12 10, 2001'},
#  {'reviewerID': 'AZIXMVXLE11G3',
#   'asin': 'B0000A98AC',
#   'reviewerName': 'Waldorf1',
#   'helpful': [0, 0],
#   'reviewText': 'One by one, all of the discs went bad within a 6 months period. It was a real pain. As a result, I would tend to not buy Memorex discs again.',
#   'overall': 1.0,
#   'summary': 'Memorex Discs',
#   'unixReviewTime': 1394928000,
#   'reviewTime': '03 16, 2014'}]

# %% [markdown]
# The ratings are stored in the keyword `"overall"`. You should create an array of the ratings for each review, preferably using list comprehensions.

# %%
ratings = [x['overall'] for x in data]

# %%
ratings[:5]
# Out:
# [5.0, 1.0, 4.0, 5.0, 3.0]

# %% [markdown]
# **Note**, the test set used by the grader is in the same format as that of `data`, a list of dictionaries. Your trained model needs to accept data in the same format. Thus, you should use `Pipeline` when constructing your model so that all necessary transformation needed are encapsulated into a single estimator object.

# %% [markdown]
# ## Question 1: Bag of words model
#
# Construct a machine learning model trained on word counts using the bag of words algorithm. Remember, the bag of words is implemented with `CountVectorizer`. Some things you should consider:
#
# * The reference solution uses a linear model and you should as well; use either `Ridge` or `SGDRegressor`.
# * The text review is stored in the key `"reviewText"`. You will need to construct a custom transformer to extract out the value of this key. It will be the first step in your pipeline.
# * Consider what hyperparameters you will need to tune for your model.
# * Subsampling the training data will boost training times, which will be helpful when determining the best hyperparameters to use. Note, your final model will perform best if it is trained on the full data set.
# * Including stop words may help with performance.

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class KeySelector(BaseEstimator, TransformerMixin):
    
    def __init__(self, key):
        self.key = key
        
    def fit(self,X, y=None):
        return self
    
    def transform(self,X):
        return [d[self.key]for d in X]

# %%
KeySelector("reviewText").fit_transform(data)[:3]
# Out:
# ["I bought this mouse to use with my laptop because I don't like those little touchpads.  I could not be happier.Since it's USB, I can plug it in with the computer already on and expect it to work automatically.  Since it's optical (the new kind, not to be confused with the old Sun optical mice that required a special checkered mouse pad) it works on most surfaces, including my pant legs, my couch, and random tables that I put my laptop down on.  It's also light and durable, features that help with portability.The wheel is surprisingly useful.  In addition to scrolling, it controls zoom and pan in programs like Autocad and 3D Studio Max.  I can no longer bear using either of these programs without it.One complaint - the software included with the Internet navigation features is useless.  Don't bother installing it if you have a newer Windows version that automatically supports wheel mice.  Just plug it in and use it - it's that easy.",
#  'One by one, all of the discs went bad within a 6 months period. It was a real pain. As a result, I would tend to not buy Memorex discs again.',
#  'Easy to install.  Works well.  No complaints.  Decent (not great) value.  Works better than the first amplifier (different brand) that I purchased.']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
bag_of_words_model = Pipeline([
    ("select_text", KeySelector('reviewText')),
    ("vectorizer", CountVectorizer(stop_words = 'english')),
    ('regressor', GridSearchCV(Ridge(), 
                              param_grid= {'alpha': np.logspace(-1,3,10)},
                              cv=5))
                           
])

# %%
bag_of_words_model.fit(data, ratings)
# Out:
# Pipeline(steps=[('select_text', KeySelector(key='reviewText')),
#                 ('vectorizer', CountVectorizer(stop_words='english')),
#                 ('regressor',
#                  GridSearchCV(cv=5, estimator=Ridge(),
#                               param_grid={'alpha': array([1.00000000e-01, 2.78255940e-01, 7.74263683e-01, 2.15443469e+00,
#        5.99484250e+00, 1.66810054e+01, 4.64158883e+01, 1.29154967e+02,
#        3.59381366e+02, 1.00000000e+03])}))])

# %%
bag_of_words_model.score(data, ratings)
# Out:
# 0.40109149298944113

# %%
bag_of_words_model.predict(data)[:10]
# Out:
# array([4.07881023, 3.34877818, 4.71352638, 4.44751994, 3.93731306,
#        4.8432953 , 4.46580972, 4.11563883, 3.96989081, 4.08209632])

# %%
grader.score.nlp__bag_of_words_model(bag_of_words_model.predict)
# Out:
# ==================
# Your score: 1.045
# ==================

# %%
bag_of_words_model.named_steps['regressor'].best_params_
# Out:
# {'alpha': 359.38136638046257}

# %%
bag_of_words_model.named_steps['vectorizer'].vocabulary_
# Out:
# {'bought': 11721,
#  'mouse': 38703,
#  'use': 61859,
#  'laptop': 34336,
#  'don': 20569,
#  'like': 35145,
#  'little': 35373,
#  'touchpads': 59469,
#  'happier': 28673,
#  'usb': 61826,
#  'plug': 44490,
#  'computer': 15876,
#  'expect': 23718,
#  'work': 64727,
#  'automatically': 9354,
#  'optical': 41572,
#  'new': 39921,
#  'kind': 33773,
#  'confused': 16132,
#  'old': 41202,
#  'sun': 56314,
#  'mice': 37560,
#  'required': 49121,
#  'special': 54373,
#  'checkered': 14216,
#  'pad': 42507,
#  'works': 64783,
#  'surfaces': 56566,
#  'including': 31193,
#  'pant': 42712,
#  'legs': 34668,
#  'couch': 16993,
#  'random': 47404,
#  'tables': 57199,
#  'light': 35056,
#  'durable': 21246,
#  'features': 24656,
#  'help': 29346,
#  'portability': 44905,
#  'wheel': 63961,
#  'surprisingly': 56621,
#  'useful': 61885,
#  'addition': 6425,
#  'scrolling': 51372,
#  'controls': 16607,
#  'zoom': 65799,
#  'pan': 42643,
#  'programs': 46041,
#  'autocad': 9312,
#  '3d': 3023,
#  'studio': 55894,
#  'max': 36889,
#  'longer': 35615,
#  'bear': 10426,
#  'using': 61944,
#  'complaint': 15716,
#  'software': 53782,
#  'included': 31184,
#  'internet': 32165,
#  'navigation': 39548,
#  'useless': 61905,
#  'bother': 11685,
#  'installing': 31846,
#  'newer': 39933,
#  'windows': 64309,
#  'version': 62528,
#  'supports': 56501,
#  'just': 33367,
#  'easy': 21755,
#  'discs': 19962,
#  'went': 63822,
#  'bad': 9895,
#  'months': 38493,
#  'period': 43475,
#  'real': 47705,
#  'pain': 42547,
#  'result': 49409,
#  'tend': 57807,
#  'buy': 12580,
#  'memorex': 37282,
#  'install': 31822,
#  'complaints': 15717,
#  'decent': 18475,
#  'great': 27911,
#  'value': 62221,
#  'better': 10801,
#  'amplifier': 7647,
#  'different': 19521,
#  'brand': 11885,
#  'purchased': 46642,
#  'item': 32759,
#  'exactly': 23426,
#  'looking': 35651,
#  'low': 35790,
#  'featured': 24649,
#  'samsung': 50811,
#  'surround': 56640,
#  'sound': 54072,
#  'realized': 47730,
#  'needed': 39701,
#  'inputs': 31722,
#  'advantage': 6657,
#  'manual': 36565,
#  'turn': 60327,
#  'switches': 56861,
#  'looked': 35646,
#  'cheap': 14169,
#  'unusable': 61571,
#  'perfect': 43381,
#  'able': 5819,
#  'remotely': 48830,
#  'control': 16577,
#  'definitely': 18689,
#  'worth': 64837,
#  'dime': 19660,
#  'spent': 54507,
#  'replace': 48957,
#  'vcr': 62340,
#  'dvd': 21336,
#  'combo': 15355,
#  'way': 63549,
#  'run': 50430,
#  'cable': 12763,
#  'wall': 63268,
#  'rca': 47605,
#  'rest': 49360,
#  'box': 11773,
#  'coax': 15081,
#  'problem': 45825,
#  'connect': 16181,
#  'review': 49601,
#  'sabrent': 50660,
#  '44': 3312,
#  'mb': 36946,
#  '2x': 2491,
#  'floppy': 25518,
#  'disk': 20027,
#  'drive': 20930,
#  'fl': 25234,
#  'udrv': 60604,
#  'black': 11095,
#  'built': 12327,
#  'quality': 46891,
#  'comes': 15383,
#  'hardwired': 28735,
#  'connection': 16192,
#  'really': 47739,
#  'say': 51005,
#  'simple': 52802,
#  'setup': 52004,
#  'wait': 63227,
#  'drivers': 20945,
#  'load': 35451,
#  'hard': 28689,
#  'skys': 53108,
#  'cause': 13687,
#  'vignetting': 62764,
#  'especially': 23077,
#  'sky': 53085,
#  'showing': 52523,
#  'nikon': 40128,
#  'd90': 18021,
#  '18': 1234,
#  '105': 335,
#  '70': 4559,
#  '300': 2520,
#  'lens': 34728,
#  'possible': 45031,
#  'secrets': 51589,
#  'know': 33931,
#  'tried': 59949,
#  'shooting': 52391,
#  'expedition': 23742,
#  'll': 35402,
#  'update': 61639,
#  'suggestions': 56246,
#  'glad': 27328,
#  'hear': 29199,
#  'canon': 13192,
#  'hood': 29871,
#  'stamped': 55090,
#  'ew': 23379,
#  '60c': 4191,
#  'japan': 32970,
#  'unlike': 61254,
#  'et': 23165,
#  '60': 4140,
#  'got': 27647,
#  'seller': 51727,
#  'returned': 49534,
#  'material': 36825,
#  'fits': 25188,
#  'hassle': 28800,
#  'cap': 13229,
#  'installed': 31835,
#  'shorter': 52440,
#  'good': 27554,
#  'sennheiser': 51782,
#  'products': 45954,
#  '1000': 190,
#  'times': 58966,
#  'bose': 11669,
#  'signal': 52697,
#  'transmits': 59764,
#  'cabinet': 12758,
#  'adjust': 6518,
#  'frequency': 26204,
#  'volume': 63001,
#  'headphones': 29114,
#  'getting': 27157,
#  'stiff': 55465,
#  'lot': 35735,
#  'fall': 24345,
#  'fantastic': 24422,
#  'used': 61873,
#  'sony': 53982,
#  'headset': 29163,
#  'terms': 57881,
#  'reach': 47634,
#  'room': 50123,
#  'construction': 16376,
#  'ears': 21693,
#  'warm': 63359,
#  'wear': 63623,
#  'uncomfortable': 60834,
#  'truly': 60122,
#  'remarkable': 48772,
#  'build': 12309,
#  'solid': 53834,
#  'charging': 14122,
#  've': 62356,
#  'owned': 42328,
#  'keyboard': 33661,
#  'weeks': 63726,
#  'loving': 35788,
#  'having': 28872,
#  'sized': 52966,
#  'shifted': 52290,
#  'right': 49796,
#  'order': 41673,
#  'center': 13879,
#  'keys': 33689,
#  'monitor': 38417,
#  'viewed': 62731,
#  'bothered': 11686,
#  'solved': 53875,
#  'looks': 35662,
#  'white': 64076,
#  'letters': 34875,
#  'numbers': 40681,
#  'easier': 21725,
#  'read': 47659,
#  'helpful': 29352,
#  'stress': 55768,
#  'putting': 46736,
#  'body': 11423,
#  'past': 42931,
#  'numeric': 40690,
#  'keypad': 33684,
#  'rid': 49758,
#  'feel': 24700,
#  'difference': 19516,
#  'arm': 8547,
#  'allowed': 7297,
#  'stay': 55290,
#  'closer': 14912,
#  'feels': 24709,
#  'differences': 19517,
#  'layout': 34489,
#  'adjustment': 6532,
#  'transition': 59738,
#  'logitech': 35570,
#  'v200': 62082,
#  'cordless': 16828,
#  'combination': 15342,
#  'smaller': 53398,
#  'life': 35003,
#  'enjoyable': 22629,
#  '3m': 3058,
#  'privacy': 45753,
#  'filters': 24969,
#  'laptops': 34347,
#  'brands': 11897,
#  'hold': 29753,
#  'long': 35610,
#  'try': 60176,
#  'outdoor': 41919,
#  'speaker': 54334,
#  'played': 44346,
#  '30': 2519,
#  'seconds': 51574,
#  'stopped': 55579,
#  'working': 64764,
#  'amazon': 7509,
#  'charge': 14100,
#  'replacement': 48965,
#  'opps': 41555,
#  'thing': 58500,
#  'nicely': 40040,
#  'dead': 18379,
#  'sounded': 54100,
#  'brief': 12015,
#  'time': 58937,
#  'emailed': 22276,
#  'com': 15311,
#  'wanted': 63318,
#  'role': 50073,
#  'dice': 19442,
#  '3rd': 3088,
#  'responded': 49333,
#  'saying': 51010,
#  'widespread': 64177,
#  'originally': 41747,
#  'thought': 58630,
#  'send': 51756,
#  'additional': 6427,
#  'refunded': 48449,
#  'money': 38395,
#  'gave': 26946,
#  '10': 188,
#  'credit': 17326,
#  'account': 6071,
#  'surprised': 56618,
#  'sale': 50748,
#  'site': 52920,
#  'later': 34412,
#  'manunfacturing': 36608,
#  'defect': 18621,
#  'goes': 27506,
#  'issue': 32682,
#  'did': 19468,
#  'product': 45930,
#  'searched': 51533,
#  'customer': 17779,
#  'reviews': 49614,
#  'isolated': 32655,
#  'save': 50977,
#  'packaging': 42481,
#  'returning': 49538,
#  'price': 45599,
#  '32': 2703,
#  '00': 0,
#  'failed': 24304,
#  'leave': 34608,
#  'feedback': 24694,
#  'anothrer': 7950,
#  'hastle': 28810,
#  'defective': 18623,
#  'matter': 36859,
#  'tries': 59951,
#  'make': 36406,
#  'mention': 37338,
#  'generous': 27072,
#  'troubles': 60068,
#  'reputable': 49099,
#  'company': 15573,
#  'recommend': 48101,
#  'strongly': 55844,
#  'continue': 16492,
#  'prodcuts': 45909,
#  'future': 26590,
#  'best': 10778,
#  'luck': 35912,
#  'plastic': 44285,
#  'love': 35778,
#  'far': 24435,
#  'quite': 47117,
#  'happy': 28679,
#  'fixed': 25212,
#  'brings': 12057,
#  'photographic': 43795,
#  'roots': 50147,
#  'vendor': 62430,
#  'awsome': 9605,
#  'quicker': 47046,
#  'expected': 23726,
#  'business': 12498,
#  'gym': 28322,
#  'listing': 35325,
#  'book': 11551,
#  'lying': 36034,
#  'pillow': 44030,
#  'library': 34963,
#  'sure': 56554,
#  'noise': 40269,
#  'cancelling': 13131,
#  'didn': 19476,
#  'want': 63316,
#  'spend': 54500,
#  'pair': 42574,
#  'taking': 57291,
#  'nice': 40032,
#  'large': 34356,
#  'overheat': 42168,
#  'block': 11260,
#  'external': 23982,
#  'sounds': 54132,
#  'songs': 53952,
#  'fold': 25704,
#  'fit': 25179,
#  'easily': 21730,
#  'extercise': 23975,
#  'pockets': 44634,
#  'appear': 8250,
#  'high': 29526,
#  'audio': 9189,
#  'expert': 23812,
#  'satisfied': 50930,
#  'produce': 45921,
#  'reason': 47785,
#  'stars': 55179,
#  'modulator': 38307,
#  'cord': 16811,
#  'makes': 36412,
#  'opinion': 41514,
#  'pleased': 44412,
#  '73': 4700,
#  'years': 65454,
#  'hearing': 29205,
#  'slowly': 53339,
#  'fading': 24299,
#  'number': 40675,
#  'understand': 60954,
#  'dialog': 19404,
#  'tv': 60365,
#  'movie': 38754,
#  'music': 39123,
#  'fine': 25023,
#  'level': 34885,
#  'bass': 10204,
#  'response': 49340,
#  'handy': 28626,
#  'outside': 42022,
#  'clearly': 14773,
#  'programmer': 46034,
#  'type': 60503,
#  'hours': 30043,
#  'week': 63716,
#  'day': 18235,
#  'mavis': 36888,
#  'beacon': 10404,
#  '16': 1066,
#  'rated': 47497,
#  '155wpm': 1002,
#  'keyboards': 33667,
#  'important': 30991,
#  'quiet': 47079,
#  'allows': 7300,
#  'fast': 24490,
#  'problems': 45842,
#  'buttons': 12560,
#  'utmost': 62030,
#  'satisfaction': 50923,
#  'stability': 54997,
#  'simply': 52822,
#  'amazing': 7499,
#  'reading': 47678,
#  'decided': 18494,
#  'speakers': 54341,
#  'wasn': 63444,
#  'mind': 37796,
#  'blown': 11299,
#  'forward': 25973,
#  '20': 1571,
#  'year': 65449,
#  'completely': 15738,
#  'dried': 20905,
#  'existing': 23661,
#  'car': 13323,
#  'honestly': 29849,
#  'complain': 15709,
#  'ideal': 30560,
#  'loud': 35752,
#  'mid': 37664,
#  'frequencies': 26202,
#  'crushed': 17534,
#  'substantial': 56090,
#  'base': 10155,
#  'practically': 45256,
#  'zilch': 65744,
#  'combined': 15348,
#  'subwoofer': 56128,
#  'actually': 6295,
#  'idea': 30558,
#  'pyle': 46778,
#  'does': 20492,
#  'rate': 47496,
#  '200watts': 1689,
#  'absolutely': 5890,
#  'farce': 24442,
#  'magnet': 36311,
#  'tiny': 59031,
#  'pioneers': 44092,
#  'came': 12959,
#  'bigger': 10916,
#  'magnets': 36319,
#  'story': 55620,
#  'sheesh': 52238,
#  'opened': 41466,
#  'starting': 55210,
#  'worry': 64827,
#  'size': 52960,
#  'end': 22514,
#  'capable': 13243,
#  'coupled': 17055,
#  'amp': 7617,
#  'tonal': 59262,
#  'clarity': 14687,
#  'range': 47413,
#  'think': 58519,
#  'gets': 27149,
#  'requires': 49128,
#  'eq': 22853,
#  'band': 10026,
#  'away': 9554,
#  'limited': 35192,
#  'regards': 48482,
#  'output': 42000,
#  'dash': 18173,
#  'design': 19081,
#  'stick': 55444,
#  'alot': 7352,
#  'inside': 31765,
#  'diameter': 19415,
#  'wise': 64446,
#  'ok': 41174,
#  'wedge': 63702,
#  'bits': 11066,
#  'grille': 27995,
#  'bulging': 12353,
#  'guys': 28292,
#  'throwing': 58728,
#  'bind': 10972,
#  'financial': 25000,
#  'wife': 64198,
#  'saving': 50986,
#  '40': 3122,
#  'dropping': 20988,
#  'minox': 37900,
#  'fan': 24389,
#  'owner': 42329,
#  '1969': 1406,
#  'gadget': 26752,
#  'lover': 35781,
#  'eager': 21614,
#  'touted': 59504,
#  'gem': 27028,
#  'worked': 64747,
#  'research': 49177,
#  'data': 18182,
#  'line': 35213,
#  'prepurchase': 45467,
#  'info': 31526,
#  'beginners': 10593,
#  'camera': 12974,
#  'close': 14905,
#  'photograph': 43790,
#  'accompanying': 6056,
#  'fancy': 24401,
#  'digital': 19603,
#  'cameras': 13001,
#  'family': 24382,
#  'friends': 26262,
#  'panasonic': 42656,
#  'palmcorder': 42607,
#  'aware': 9551,
#  'imaging': 30835,
#  'performance': 43432,
#  'performed': 43443,
#  'operation': 41500,
#  'menu': 37344,
#  'lcd': 34511,
#  'indicator': 31359,
#  'photos': 43837,
#  'reasonably': 47790,
#  'sharp': 52164,
#  'given': 27309,
#  'accompanaying': 6051,
#  'superbly': 56365,
#  'usable': 61807,
#  'duracell': 21257,
#  'aaa': 5728,
#  'battery': 10295,
#  'noted': 40477,
#  'connoting': 16239,
#  'note': 40468,
#  'tyring': 60532,
#  'webcam': 63657,
#  'images': 30808,
#  'produced': 45922,
#  'typically': 60522,
#  'sub': 56000,
#  'mediocre': 37160,
#  'webcams': 63662,
#  'indoor': 31399,
#  'shots': 52465,
#  'bit': 11047,
#  'fuzzy': 26607,
#  'son': 53937,
#  'took': 59300,
#  'panorama': 42701,
#  'shot': 52459,
#  'seminar': 51743,
#  'giving': 27317,
#  'stitched': 55520,
#  'broad': 12079,
#  'wrong': 65009,
#  'delayed': 18781,
#  'beep': 10537,
#  'indicate': 31350,
#  'photo': 43758,
#  'exposure': 23897,
#  'starts': 55218,
#  'indicates': 31352,
#  'stops': 55584,
#  'dim': 19658,
#  'couple': 17054,
#  'flaws': 25381,
#  'sent': 51841,
#  'image': 30793,
#  'blurred': 11361,
#  'edges': 21881,
#  'posted': 45044,
#  'british': 12069,
#  'live': 35381,
#  'second': 51564,
#  'drains': 20828,
#  'disturbingly': 20308,
#  'rapidly': 47461,
#  'storing': 55610,
#  'pictures': 43958,
#  'trouble': 60064,
#  'weekend': 63720,
#  'trip': 59991,
#  'drained': 20823,
#  'days': 18251,
#  'leaving': 34612,
#  'download': 20737,
#  'soon': 53998,
#  'experiment': 23797,
#  'systematically': 57056,
#  'changed': 14044,
#  'quickly': 47053,
#  'changing': 14055,
#  'instructions': 31904,
#  'lose': 35720,
#  'change': 14040,
#  'batteries': 10271,
#  'mechanism': 37116,
#  'socond': 53742,
#  'conclusion': 15961,
#  'sipix': 52898,
#  'blink': 11225,
#  'general': 27046,
#  'public': 46499,
#  'experience': 23788,
#  'subminiature': 56053,
#  'owners': 42331,
#  'enjoyed': 22633,
#  'decades': 18457,
#  'takes': 57287,
#  'currently': 17723,
#  'breakthrough': 11950,
#  'throughly': 58710,
#  'fun': 26479,
#  'affordable': 6807,
#  'insurance': 31943,
#  'purposes': 46695,
#  'carry': 13468,
#  'needing': 39709,
#  'jim': 33107,
#  'true': 60103,
#  'cables': 12792,
#  'provide': 46338,
#  'buys': 12599,
#  'monster': 38473,
#  'refuting': 48471,
#  'durability': 21243,
#  'case': 13522,
#  'knowing': 33932,
#  'equipment': 22906,
#  'investment': 32369,
#  'admit': 6569,
#  'arista': 8535,
#  'fiber': 24825,
#  'optic': 41571,
#  'length': 34703,
#  'cheaper': 14178,
#  'foot': 25772,
#  'traffic': 59619,
#  'fair': 24319,
#  'belkin': 10657,
#  'network': 39877,
#  'produces': 45926,
#  'conduction': 16026,
#  'firmware': 25138,
#  'bd': 10378,
#  'player': 44348,
#  'penny': 43295,
#  'series': 51915,
#  'lenses': 34760,
#  'usually': 61989,
#  'shoot': 52383,
#  'portraits': 44954,
#  'people': 43321,
#  'need': 39696,
#  'wide': 64163,
#  'angle': 7838,
#  'reported': 49024,
#  'heavy': 29254,
#  'santa': 50861,
#  'claus': 14728,
#  'doesn': 20496,
#  'exist': 23652,
#  'received': 47911,
#  '200': 1572,
#  'previously': 45587,
#  'daughter': 18219,
#  'birthday': 11039,
#  'party': 42886,
#  'captured': 13310,
#  'uniqueness': 61194,
#  'barn': 10128,
#  'property': 46179,
#  'cropping': 17452,
#  '20d': 1791,
#  'course': 17066,
#  '5d': 4013,
#  'photography': 43800,
#  'passion': 42914,
#  'living': 35395,
#  'youthful': 65595,
#  'play': 44332,
#  'restored': 49384,
#  'lie': 34992,
#  'leaves': 34610,
#  'tree': 59875,
#  'house': 30051,
#  'jumped': 33325,
#  'bed': 10504,
#  'plumenting': 44522,
#  'floor': 25501,
#  'cracked': 17177,
#  'filter': 24943,
#  'jammed': 32952,
#  'knew': 33896,
#  '15': 947,
#  'hit': 29647,
#  'adding': 6422,
#  'considering': 16295,
#  'backback': 9798,
#  'wonderful': 64653,
#  'padded': 42510,
#  'huge': 30256,
#  'label': 34172,
#  'cost': 16956,
#  'broken': 12115,
#  'sarah': 50874,
#  'school': 51178,
#  'stuff': 55908,
#  'likely': 35154,
#  'stolen': 55550,
#  'remember': 48794,
#  'throw': 58719,
#  'kid': 33741,
#  'husband': 30355,
#  'wireless': 64414,
#  'watching': 63470,
#  'deficit': 18662,
#  'hardly': 28716,
#  'recently': 47936,
#  '120': 575,
#  'comparison': 15599,
#  'comfort': 15399,
#  'bedroom': 10510,
#  'granddaughter': 27802,
#  'christmas': 14448,
#  'delivered': 18821,
#  'promised': 46105,
#  'condition': 16001,
#  'thank': 58008,
#  'wrt54g': 65030,
#  'router': 50222,
#  'linksys': 35261,
#  'seriously': 51921,
#  'damaged': 18077,
#  'removing': 48849,
#  'rp': 50263,
#  'tnc': 59137,
#  'antenna': 8002,
#  'connectors': 16214,
#  'units': 61215,
#  'wrt54gl': 65034,
#  'making': 36420,
#  'standard': 55104,
#  'antennas': 8014,
#  'stronger': 55840,
#  'increase': 31270,
#  'instead': 31867,
#  'pny': 44592,
#  'optima': 41592,
#  '512mb': 3742,
#  'ddr': 18352,
#  '333': 2802,
#  'mhz': 37546,
#  'pc2700': 43064,
#  'desktop': 19139,
#  'dimm': 19679,
#  'memory': 37294,
#  'module': 38309,
#  'md0512sd1': 37013,
#  'doctor': 20459,
#  'ordered': 41675,
#  'pick': 43906,
#  'aging': 6933,
#  'pc': 43051,
#  'increased': 31271,
#  'ram': 47375,
#  'noticeable': 40503,
#  'enhancement': 22617,
#  'speed': 54447,
#  'operations': 41507,
#  'prime': 45668,
#  'shipping': 52330,
#  'installation': 31827,
#  'beat': 10442,
#  'havent': 28859,
#  'fully': 26471,
#  'tested': 57920,
#  'microphone': 37622,
#  'adjustable': 6522,
#  'comfortable': 15401,
#  'incredible': 31281,
#  'games': 26828,
#  'highly': 29550,
#  'spends': 54504,
#  'phone': 43727,
#  'talking': 57314,
#  'customers': 17781,
#  'trying': 60181,
#  'variety': 62291,
#  'phones': 43736,
#  'handsets': 28608,
#  'determined': 19250,
#  'obtained': 40869,
#  'headsets': 29165,
#  'inexpensive': 31449,
#  'available': 9429,
#  'locally': 35492,
#  'broke': 12113,
#  'turned': 60331,
#  'jewel': 33073,
#  'offers': 41039,
#  'date': 18207,
#  'separate': 51858,
#  '5mm': 4084,
#  'socket': 53735,
#  'fact': 24279,
#  'mentioned': 37339,
#  'description': 19048,
#  'state': 55237,
#  'quick': 47038,
#  'disconnect': 19895,
#  'feature': 24645,
#  'added': 6407,
#  'freedom': 26143,
#  'imply': 30983,
#  'terminates': 57874,
#  'corresponding': 16916,
#  'extra': 23996,
#  'excellent': 23490,
#  'clear': 14760,
#  'trusty': 60150,
#  'microsoft': 37642,
#  'intellimouse': 32002,
#  'explorer': 23870,
#  'failing': 24306,
#  'chose': 14433,
#  'switch': 56847,
#  'kensington': 33625,
#  'based': 10162,
#  'btw': 12221,
#  'xp': 65302,
#  'compared': 15589,
#  'previous': 45586,
#  'seen': 51654,
#  'provides': 46347,
#  'silky': 52752,
#  'touch': 59457,
#  'basic': 10184,
#  'fingerprint': 25051,
#  'clicker': 14805,
#  'positive': 45007,
#  'click': 14801,
#  'mushiness': 39118,
#  'scroll': 51367,
#  'performs': 43452,
#  'smoothly': 53522,
#  'programmed': 46033,
#  'mouseworks': 38726,
#  'program': 46018,
#  'left': 34629,
#  'button': 12551,
#  'screen': 51311,
#  'refresh': 48427,
#  'options': 41621,
#  'missing': 38034,
#  'led': 34617,
#  'jazz': 32997,
#  'awesome': 9571,
#  'latest': 34419,
#  'enclosed': 22447,
#  'cd': 13753,
#  'probably': 45806,
#  'apply': 8309,
#  'isolation': 32659,
#  'earphones': 21677,
#  'require': 49119,
#  'insert': 31754,
#  'ear': 21625,
#  'canal': 13109,
#  'plugs': 44512,
#  'word': 64707,
#  'e2cs': 21516,
#  'come': 15366,
#  'seven': 52016,
#  'types': 60513,
#  'buds': 12269,
#  'necessary': 39670,
#  'apparently': 8242,
#  'narrow': 39483,
#  'canals': 13113,
#  'ones': 41335,
#  'smallest': 53401,
#  'main': 36368,
#  'normal': 40406,
#  'bud': 12253,
#  'slightest': 53235,
#  'head': 29063,
#  'shake': 52102,
#  'jogging': 33167,
#  'wouldn': 64867,
#  'walking': 63259,
#  'sort': 54041,
#  'ache': 6147,
#  'decide': 18493,
#  'shure': 52590,
#  'website': 63686,
#  'link': 35245,
#  'guarantee': 28176,
#  'local': 35486,
#  'store': 55595,
#  'unlikely': 61255,
#  'open': 41458,
#  'package': 42475,
#  'let': 34858,
#  'test': 57916,
#  'stores': 55603,
#  'accept': 5968,
#  'returns': 49539,
#  'ask': 8768,
#  'return': 49531,
#  'policy': 44737,
#  'accurate': 6113,
#  'things': 58509,
#  'isolate': 32654,
#  'blocking': 11267,
#  '95': 5380,
#  'listening': 35315,
#  'rock': 50014,
#  'acoustic': 6206,
#  'subway': 56123,
#  'soundtrack': 54152,
#  'headphone': 29110,
#  'gives': 27314,
#  'portable': 44909,
#  'greatest': 27920,
#  'strength': 55758,
#  'limitation': 35190,
#  'imagine': 30831,
#  'going': 27514,
#  'point': 44683,
#  'jog': 33162,
#  'dangerous': 18119,
#  'unless': 61251,
#  'deserted': 19069,
#  'area': 8478,
#  'totally': 59438,
#  'hiking': 29577,
#  'chancy': 14033,
#  'walk': 63249,
#  'crowded': 17488,
#  'areas': 8480,
#  'lost': 35734,
#  'count': 17018,
#  'bumped': 12388,
#  'realize': 47729,
#  'unconsciously': 60856,
#  'rely': 48753,
#  'eat': 21767,
#  ...}

# %%
bag_of_words_model.named_steps['vectorizer'].get_feature_names()[11721]
# Out:
# 'bought'

# %% [markdown]
# ## Question 2: Normalized model
#
# Using raw counts will not be as effective compared if we had normalized the counts. There are several ways to normalize raw counts; the `HashingVectorizer` class has the keyword `norm` and there is also the `TfidfTransformer` and `TfidfVectorizer` that perform tf-idf weighting on the counts. Apply normalization to your model to improve performance.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

normalized_model = Pipeline([
    ('selector', KeySelector('reviewText')),
    ('vectorizer', TfidfVectorizer(stop_words='english')),
    ('model', Ridge())])
normalized_model.fit(data, ratings)
# Out:
# Pipeline(steps=[('selector', KeySelector(key='reviewText')),
#                 ('vectorizer', TfidfVectorizer(stop_words='english')),
#                 ('model', Ridge())])

# %%
normalized_model.score(data,ratings)
# Out:
# 0.6025417722330686

# %%
grader.score.nlp__normalized_model(normalized_model.predict)
# Out:
# ==================
# Your score: 0.993
# ==================

# %% [markdown]
# ## Question 3: Bigrams model
#
# The model performance may increase when including additional features generated by counting bigrams. Include bigrams to your model. When using more features, the risk of overfitting increases. Make sure you try to minimize overfitting as much as possible.

# %%
bigrams_model = Pipeline([
    ('selector', KeySelector('reviewText')),
    ('vectorizer',TfidfVectorizer(stop_words = 'english', ngram_range=(1,2))),
    ('regressor', Ridge())
    
])

# %%
bigrams_model.fit(data, ratings)
# Out:
# Pipeline(steps=[('selector', KeySelector(key='reviewText')),
#                 ('vectorizer',
#                  TfidfVectorizer(ngram_range=(1, 2), stop_words='english')),
#                 ('regressor', Ridge())])

# %%
grader.score.nlp__bigrams_model(bigrams_model.predict)
# Out:
# ==================
# Your score: 1.033
# ==================

# %%
bigrams_model.score(data, ratings)
# Out:
# 0.8263560931212581

# %%
bigrams_model.named_steps['vectorizer'].vocabulary_
# Out:
# {'bought': 179469,
#  'mouse': 869568,
#  'use': 1446249,
#  'laptop': 735441,
#  'don': 415493,
#  'like': 764355,
#  'little': 779051,
#  'touchpads': 1396630,
#  'happier': 609065,
#  'usb': 1445198,
#  'plug': 1008698,
#  'computer': 301445,
#  'expect': 478258,
#  'work': 1525146,
#  'automatically': 123386,
#  'optical': 933215,
#  'new': 894914,
#  'kind': 723057,
#  'confused': 308964,
#  'old': 923854,
#  'sun': 1330230,
#  'mice': 842313,
#  'required': 1139500,
#  'special': 1282630,
#  'checkered': 259028,
#  'pad': 952030,
#  'works': 1530770,
#  'surfaces': 1338780,
#  'including': 670869,
#  'pant': 959802,
#  'legs': 747698,
#  'couch': 334705,
#  'random': 1092274,
#  'tables': 1348535,
#  'light': 760644,
#  'durable': 431713,
#  'features': 508246,
#  'help': 629674,
#  'portability': 1021144,
#  'wheel': 1508816,
#  'surprisingly': 1340360,
#  'useful': 1454740,
#  'addition': 70511,
#  'scrolling': 1191601,
#  'controls': 323964,
#  'zoom': 1550557,
#  'pan': 958370,
#  'programs': 1059677,
#  'autocad': 122728,
#  '3d': 31538,
#  'studio': 1320024,
#  'max': 827950,
#  'longer': 790339,
#  'bear': 149022,
#  'using': 1458160,
#  'complaint': 297204,
#  'software': 1261884,
#  'included': 669633,
#  'internet': 692122,
#  'navigation': 882470,
#  'useless': 1455641,
#  'bother': 178649,
#  'installing': 684604,
#  'newer': 897143,
#  'windows': 1514444,
#  'version': 1471735,
#  'supports': 1334956,
#  'just': 712391,
#  'easy': 443912,
#  'bought mouse': 181063,
#  'mouse use': 871007,
#  'use laptop': 1448763,
#  'laptop don': 735868,
#  'don like': 416385,
#  'like little': 766863,
#  'little touchpads': 781297,
#  'touchpads happier': 1396632,
#  'happier usb': 609264,
#  'usb plug': 1445781,
#  'plug computer': 1008925,
#  'computer expect': 302080,
#  'expect work': 479117,
#  'work automatically': 1525398,
#  'automatically optical': 123586,
#  'optical new': 933433,
#  'new kind': 895938,
#  'kind confused': 723198,
#  'confused old': 309028,
#  'old sun': 925281,
#  'sun optical': 1330373,
#  'optical mice': 933422,
#  'mice required': 842567,
#  'required special': 1139889,
#  'special checkered': 1282689,
#  'checkered mouse': 259030,
#  'mouse pad': 870526,
#  'pad works': 952493,
#  'works surfaces': 1532452,
#  'surfaces including': 1338837,
#  'including pant': 671354,
#  'pant legs': 959805,
#  'legs couch': 747750,
#  'couch random': 334769,
#  'random tables': 1092412,
#  'tables laptop': 1348550,
#  'laptop light': 736199,
#  'light durable': 761172,
#  'durable features': 431883,
#  'features help': 508717,
#  'help portability': 630271,
#  'portability wheel': 1021302,
#  'wheel surprisingly': 1509250,
#  'surprisingly useful': 1340512,
#  'useful addition': 1454765,
#  'addition scrolling': 70922,
#  'scrolling controls': 1191622,
#  'controls zoom': 324531,
#  'zoom pan': 1551242,
#  'pan programs': 958426,
#  'programs like': 1059861,
#  'like autocad': 764796,
#  'autocad 3d': 122729,
#  '3d studio': 31604,
#  'studio max': 1320176,
#  'max longer': 828079,
#  'longer bear': 790443,
#  'bear using': 149057,
#  'using programs': 1460242,
#  'programs complaint': 1059744,
#  'complaint software': 297646,
#  'software included': 1262532,
#  'included internet': 670046,
#  'internet navigation': 692503,
#  'navigation features': 882514,
#  'features useless': 509361,
#  'useless don': 1455765,
#  'don bother': 415683,
#  'bother installing': 178794,
#  'installing newer': 684774,
#  'newer windows': 897500,
#  'windows version': 1515112,
#  'version automatically': 1471869,
#  'automatically supports': 123692,
#  'supports wheel': 1335244,
#  'wheel mice': 1509075,
#  'mice just': 842462,
#  'just plug': 714685,
#  'plug use': 1009844,
#  'use easy': 1447726,
#  'discs': 401742,
#  'went': 1506609,
#  'bad': 133370,
#  'months': 864670,
#  'period': 977573,
#  'real': 1101461,
#  'pain': 954761,
#  'result': 1146264,
#  'tend': 1361996,
#  'buy': 204683,
#  'memorex': 835755,
#  'discs went': 402250,
#  'went bad': 1506698,
#  'bad months': 134080,
#  'months period': 865299,
#  'period real': 977736,
#  'real pain': 1101859,
#  'pain result': 955078,
#  'result tend': 1146615,
#  'tend buy': 1362028,
#  'buy memorex': 205909,
#  'memorex discs': 835803,
#  'install': 682115,
#  'complaints': 297759,
#  'decent': 363456,
#  'great': 591354,
#  'value': 1464803,
#  'better': 157924,
#  'amplifier': 94496,
#  'different': 390851,
#  'brand': 185549,
#  'purchased': 1072568,
#  'easy install': 444525,
#  'install works': 683052,
#  'works complaints': 1531120,
#  'complaints decent': 297856,
#  'decent great': 363719,
#  'great value': 594537,
#  'value works': 1465526,
#  'works better': 1530982,
#  'better amplifier': 158128,
#  'amplifier different': 94579,
#  'different brand': 390974,
#  'brand purchased': 186098,
#  'item': 703113,
#  'exactly': 472136,
#  'looking': 793442,
#  'low': 803912,
#  'featured': 508167,
#  'samsung': 1177573,
#  'surround': 1340561,
#  'sound': 1271929,
#  'realized': 1102733,
#  'needed': 888010,
#  'inputs': 679718,
#  'advantage': 76355,
#  'manual': 820313,
#  'turn': 1418166,
#  'switches': 1344748,
#  'looked': 792902,
#  'cheap': 255446,
#  'unusable': 1439346,
#  'perfect': 972891,
#  'able': 55396,
#  'remotely': 1131119,
#  'control': 322291,
#  'definitely': 368270,
#  'worth': 1535262,
#  'dime': 394833,
#  'spent': 1287129,
#  'item exactly': 703426,
#  'exactly looking': 472397,
#  'looking purchased': 794473,
#  'purchased low': 1073421,
#  'low featured': 804161,
#  'featured samsung': 508216,
#  'samsung surround': 1177761,
#  'surround sound': 1340700,
#  'sound realized': 1273808,
#  'realized needed': 1102893,
#  'needed optical': 888848,
#  'optical inputs': 933380,
#  'inputs advantage': 679731,
#  'advantage manual': 76534,
#  'manual turn': 821049,
#  'turn switches': 1418992,
#  'switches looked': 1344910,
#  'looked cheap': 792979,
#  'cheap unusable': 256682,
#  'unusable perfect': 1439429,
#  'perfect able': 972930,
#  'able remotely': 56175,
#  'remotely control': 1131133,
#  'control definitely': 322564,
#  'definitely worth': 368973,
#  'worth dime': 1535500,
#  'dime spent': 394870,
#  'replace': 1134365,
#  'vcr': 1467210,
#  'dvd': 433555,
#  'combo': 283032,
#  'way': 1496962,
#  'run': 1170174,
#  'cable': 209261,
#  'wall': 1486158,
#  'rca': 1097412,
#  'rest': 1145175,
#  'box': 182597,
#  'coax': 277478,
#  'problem': 1047738,
#  'connect': 309462,
#  'purchased replace': 1073721,
#  'replace vcr': 1135165,
#  'vcr dvd': 1467323,
#  'dvd combo': 433733,
#  'combo way': 283240,
#  'way run': 1498775,
#  'run cable': 1170339,
#  'cable wall': 211537,
#  'wall rca': 1486623,
#  'rca rest': 1097635,
#  'rest box': 1145219,
#  'box box': 182750,
#  'box work': 184087,
#  'work rca': 1527156,
#  'rca rca': 1097623,
#  'rca coax': 1097473,
#  'coax rca': 277553,
#  'rca problem': 1097607,
#  'problem way': 1049949,
#  'way connect': 1497439,
#  'connect wall': 310242,
#  'wall cable': 1486256,
#  'cable newer': 210619,
#  'newer dvd': 897234,
#  'dvd vcr': 434534,
#  'vcr coax': 1467277,
#  'coax cable': 277491,
#  'review': 1150608,
#  'sabrent': 1174519,
#  '44': 34409,
#  'mb': 829749,
#  '2x': 25303,
#  'floppy': 537916,
#  'disk': 402688,
#  'drive': 423595,
#  'fl': 531074,
#  'udrv': 1426251,
#  'black': 167527,
#  'built': 197353,
#  'quality': 1078308,
#  'comes': 284739,
#  'hardwired': 612501,
#  'connection': 311326,
#  'really': 1103073,
#  'say': 1182011,
#  'simple': 1237570,
#  'setup': 1214105,
#  'wait': 1484305,
#  'drivers': 425787,
#  'load': 784028,
#  'hard': 610376,
#  'review sabrent': 1151539,
#  'sabrent usb': 1174529,
#  'usb 44': 1445218,
#  '44 mb': 34437,
#  'mb 2x': 829764,
#  '2x floppy': 25352,
#  'floppy disk': 537945,
#  'disk drive': 402815,
#  'drive fl': 424110,
#  'fl udrv': 531098,
#  'udrv black': 1426252,
#  'black built': 167609,
#  'built quality': 198114,
#  'quality floppy': 1079392,
#  'drive comes': 423860,
#  'comes hardwired': 285323,
#  'hardwired usb': 612534,
#  'usb cable': 1445309,
#  'cable connection': 209708,
#  'connection computer': 311516,
#  'computer really': 302938,
#  'really say': 1104542,
#  'say works': 1183797,
#  'works simple': 1532332,
#  'simple setup': 1238335,
#  'setup plug': 1214759,
#  'plug wait': 1009863,
#  'wait drivers': 1484398,
#  'drivers load': 426098,
#  'load install': 784214,
#  'install use': 682999,
#  'use drive': 1447651,
#  'drive hard': 424182,
#  'skys': 1247324,
#  'cause': 241067,
#  'vignetting': 1477612,
#  'especially': 467153,
#  'sky': 1246915,
#  'showing': 1230420,
#  'nikon': 902281,
#  'd90': 353358,
#  '18': 12745,
#  '105': 4663,
#  '70': 45106,
#  '300': 26021,
#  'lens': 749341,
#  'possible': 1025094,
#  'secrets': 1196376,
#  'know': 727193,
#  'tried': 1406428,
#  'shooting': 1224246,
#  'expedition': 480679,
#  'll': 782641,
#  'update': 1440099,
#  'suggestions': 1329072,
#  'glad': 575349,
#  'hear': 624506,
#  'works skys': 1532338,
#  'skys cause': 1247326,
#  'cause vignetting': 241527,
#  'vignetting especially': 1477668,
#  'especially using': 468165,
#  'using sky': 1460566,
#  'sky showing': 1247083,
#  'showing using': 1230571,
#  'using nikon': 1459956,
#  'nikon d90': 902555,
#  'd90 18': 353362,
#  '18 105': 12753,
#  '105 70': 4680,
#  '70 300': 45146,
#  '300 lens': 26231,
#  'lens possible': 751843,
#  'possible secrets': 1025574,
#  'secrets using': 1196384,
#  'using don': 1459014,
#  'don know': 416347,
#  'know tried': 728815,
#  'tried shooting': 1407554,
#  'shooting expedition': 1224513,
#  'expedition use': 480694,
#  'use like': 1448850,
#  'like better': 764911,
#  'better ll': 159325,
#  'll update': 783794,
#  'update review': 1440652,
#  'review suggestions': 1151663,
#  'suggestions use': 1329145,
#  'use ll': 1448883,
#  'll glad': 783091,
#  'glad hear': 575459,
#  'canon': 223739,
#  'hood': 642796,
#  'stamped': 1294032,
#  'ew': 471635,
#  '60c': 42771,
#  'japan': 706995,
#  'unlike': 1436482,
#  'et': 469059,
#  '60': 41979,
#  'got': 585567,
#  'seller': 1200869,
#  'returned': 1149214,
#  'material': 826377,
#  'fits': 529044,
#  'hassle': 613206,
#  'cap': 225593,
#  'installed': 683623,
#  'shorter': 1226998,
#  'real canon': 1101545,
#  'canon lens': 224470,
#  'lens hood': 751020,
#  'hood stamped': 643258,
#  'stamped canon': 1294039,
#  'canon ew': 224246,
#  'ew 60c': 471636,
#  '60c japan': 42776,
#  'japan unlike': 707127,
#  'unlike et': 1436629,
#  'et 60': 469062,
#  '60 got': 42126,
#  'got seller': 587357,
#  'seller returned': 1201079,
#  'returned quality': 1149488,
#  'quality material': 1079927,
#  'material fits': 826504,
#  'fits lens': 529352,
#  'lens hassle': 750960,
#  'hassle lens': 613325,
#  'lens cap': 749960,
#  'cap fits': 225757,
#  'fits hood': 529314,
#  'hood installed': 643034,
#  'installed just': 684051,
#  'just little': 714216,
#  'little longer': 780358,
#  'longer like': 790820,
#  'like et': 765893,
#  '60 little': 42174,
#  'little shorter': 780986,
#  'good': 581287,
#  'sennheiser': 1202555,
#  'products': 1056568,
#  '1000': 3627,
#  'times': 1385531,
#  'bose': 177993,
#  'signal': 1233992,
#  'transmits': 1402246,
#  'cabinet': 209035,
#  'adjust': 73309,
#  'frequency': 552742,
#  'volume': 1481391,
#  'headphones': 620705,
#  'getting': 570635,
#  'stiff': 1307723,
#  'lot': 798380,
#  'fall': 497659,
#  'fantastic': 500508,
#  'good sound': 584158,
#  'sound quality': 1273758,
#  'quality sennheiser': 1080637,
#  'sennheiser products': 1202867,
#  'products 1000': 1056572,
#  '1000 times': 3813,
#  'times better': 1385660,
#  'better bose': 158271,
#  'bose signal': 178421,
#  'signal transmits': 1234969,
#  'transmits cabinet': 1402252,
#  'cabinet adjust': 209037,
#  'adjust frequency': 73475,
#  'frequency volume': 553082,
#  'volume headphones': 1481802,
#  'headphones getting': 621520,
#  'getting problem': 571631,
#  'problem little': 1048886,
#  'little stiff': 781133,
#  'stiff lot': 1307825,
#  'lot fall': 798926,
#  'fall fantastic': 497809,
#  'used': 1451480,
#  'sony': 1268255,
#  'headset': 623279,
#  'terms': 1363373,
#  'reach': 1097801,
#  'room': 1162876,
#  'construction': 318522,
#  'ears': 440355,
#  'warm': 1491814,
#  'wear': 1500413,
#  'uncomfortable': 1428492,
#  'truly': 1412640,
#  'remarkable': 1128812,
#  'build': 196616,
#  'solid': 1264221,
#  'charging': 254491,
#  'used sony': 1454129,
#  'sony headset': 1268990,
#  'headset better': 623350,
#  'better terms': 160397,
#  'terms sound': 1363611,
#  'quality reach': 1080449,
#  'reach room': 1098146,
#  'room construction': 1163140,
#  'construction ears': 318642,
#  'ears little': 440783,
#  'little warm': 781433,
#  'warm wear': 1492034,
#  'wear work': 1500987,
#  'work uncomfortable': 1527803,
#  'uncomfortable sound': 1428721,
#  'sound truly': 1274305,
#  'truly remarkable': 1412904,
#  'remarkable build': 1128818,
#  'build solid': 196949,
#  'solid charging': 1264340,
#  'charging easy': 254598,
#  've': 1467718,
#  'owned': 947765,
#  'keyboard': 719575,
#  'weeks': 1504326,
#  'loving': 803848,
#  'having': 614733,
#  'sized': 1244900,
#  'shifted': 1221055,
#  'right': 1156173,
#  'order': 935902,
#  'center': 245834,
#  'keys': 721141,
#  'monitor': 861808,
#  'viewed': 1476677,
#  'bothered': 178986,
#  'solved': 1265960,
#  'looks': 794970,
#  'white': 1510016,
#  'letters': 756489,
#  'numbers': 914539,
#  'easier': 441652,
#  'read': 1098525,
#  'helpful': 630860,
#  'stress': 1316423,
#  'putting': 1076841,
#  'body': 173474,
#  'past': 964227,
#  'numeric': 914788,
#  'keypad': 721057,
#  'rid': 1155324,
#  'feel': 510155,
#  'difference': 389688,
#  'arm': 110553,
#  'allowed': 86938,
#  'stay': 1303087,
#  'closer': 274805,
#  'feels': 511495,
#  'differences': 390697,
#  'layout': 742084,
#  'adjustment': 74496,
#  'transition': 1401800,
#  'logitech': 787805,
#  'v200': 1463566,
#  'cordless': 330377,
#  'combination': 282312,
#  'smaller': 1255883,
#  'life': 759162,
#  'enjoyable': 459987,
#  've owned': 1468829,
#  'owned keyboard': 948073,
#  'keyboard weeks': 720668,
#  'weeks really': 1504721,
#  'really loving': 1104106,
#  'loving having': 803871,
#  'having sized': 615847,
#  'sized keyboard': 1245058,
#  'keyboard shifted': 720448,
#  'shifted way': 1221084,
#  'way right': 1498753,
#  'right order': 1157270,
#  'order center': 936033,
#  'center keys': 246115,
#  'keys used': 721620,
#  'used monitor': 1453288,
#  'monitor viewed': 862587,
#  'viewed having': 1476695,
#  'having reach': 615698,
#  'reach way': 1098233,
#  'way mouse': 1498321,
#  'mouse bothered': 869751,
#  'bothered keyboard': 179039,
#  'keyboard solved': 720490,
#  'solved problem': 1266060,
#  'problem looks': 1048901,
#  'looks great': 795162,
#  'great white': 594639,
#  'white letters': 1510284,
#  'letters numbers': 756554,
#  'numbers easier': 914598,
#  'easier read': 442075,
#  'read laptop': 1099058,
#  'laptop keys': 736156,
#  'keys helpful': 721337,
#  'helpful really': 631107,
#  'really don': 1103602,
#  'know stress': 728690,
#  'stress putting': 1316518,
#  'putting body': 1076894,
#  'body having': 173741,
#  'reach past': 1098091,
#  'past useless': 964728,
#  'useless numeric': 1455931,
#  'numeric keypad': 914800,
#  'keypad rid': 721097,
#  'rid feel': 1155382,
#  'feel difference': 510377,
#  'difference arm': 389789,
#  'arm allowed': 110561,
#  'allowed stay': 87131,
#  'stay closer': 1303177,
#  'closer rest': 274977,
#  'rest feels': 1145315,
#  'feels great': 511579,
#  'great differences': 592230,
#  'differences layout': 390772,
#  'layout keyboard': 742160,
#  'keyboard sized': 720466,
#  'sized expect': 1245010,
#  'expect period': 478831,
#  'period adjustment': 977583,
#  'adjustment differences': 74563,
#  'differences easy': 390747,
#  'easy transition': 445222,
#  'transition bought': 1401806,
#  'bought logitech': 180919,
#  'logitech v200': 788275,
#  'v200 cordless': 1463567,
#  'cordless mouse': 330466,
#  'mouse combination': 869825,
#  'combination new': 282509,
#  'new smaller': 896629,
#  'smaller keyboard': 1256235,
#  'keyboard cordless': 719783,
#  'mouse life': 870329,
#  'life computer': 759358,
#  'computer enjoyable': 302045,
#  '3m': 31782,
#  'privacy': 1045425,
#  'filters': 520044,
#  'laptops': 736988,
#  'brands': 186502,
#  'hold': 637927,
#  'long': 788693,
#  '3m privacy': 31823,
#  'privacy filters': 1045442,
#  'filters laptops': 520448,
#  'laptops brand': 737022,
#  'brand use': 186306,
#  'use ve': 1451060,
#  've tried': 1469389,
#  'tried brands': 1406599,
#  'brands don': 186621,
#  'don hold': 416245,
#  'hold long': 638475,
#  'long 3m': 788724,
#  '3m brand': 31790,
#  'try': 1413741,
#  'outdoor': 941085,
#  'speaker': 1279284,
#  'played': 1002974,
#  '30': 25514,
#  'seconds': 1195698,
#  'stopped': 1309656,
#  'working': 1529346,
#  'amazon': 91374,
#  'charge': 252596,
#  'replacement': 1135961,
#  'opps': 932916,
#  'thing': 1369816,
#  'nicely': 900210,
#  'dead': 361086,
#  'sounded': 1274653,
#  'brief': 189238,
#  'time': 1382083,
#  'emailed': 453493,
#  'com': 281669,
#  'wanted': 1489865,
#  'role': 1161970,
#  'dice': 386001,
#  '3rd': 31989,
#  'responded': 1144256,
#  'saying': 1183837,
#  'widespread': 1511645,
#  'originally': 939387,
#  'thought': 1376045,
#  'send': 1201775,
#  'additional': 71054,
#  'refunded': 1122779,
#  'money': 860427,
#  'gave': 565916,
#  '10': 1595,
#  'credit': 343818,
#  'account': 61368,
#  'surprised': 1339804,
#  'sale': 1176857,
#  'site': 1241204,
#  'later': 740349,
#  'manunfacturing': 822497,
#  'defect': 367278,
#  'goes': 578142,
#  'issue': 700730,
#  'did': 386173,
#  'product': 1053885,
#  'searched': 1193522,
#  'customer': 349589,
#  'reviews': 1152690,
#  'isolated': 700259,
#  'save': 1180246,
#  'packaging': 951157,
#  'returning': 1149647,
#  'price': 1038401,
#  '32': 27585,
#  '00': 0,
#  'failed': 495739,
#  'leave': 744926,
#  'feedback': 509897,
#  'anothrer': 98233,
#  'hastle': 613550,
#  'defective': 367401,
#  'matter': 827166,
#  'tries': 1407903,
#  'make': 814561,
#  'mention': 837070,
#  'generous': 569228,
#  'troubles': 1411273,
#  'reputable': 1138753,
#  'company': 291391,
#  'recommend': 1114285,
#  'strongly': 1319030,
#  'continue': 320983,
#  'prodcuts': 1052972,
#  'future': 560511,
#  'best': 156048,
#  'luck': 806224,
#  'try outdoor': 1414511,
#  'outdoor speaker': 941247,
#  'speaker played': 1280002,
#  'played 30': 1002980,
#  '30 seconds': 25928,
#  'seconds stopped': 1196191,
#  'stopped working': 1309897,
#  'working returned': 1530237,
#  'returned amazon': 1149241,
#  'amazon charge': 91637,
#  'charge got': 252835,
#  'got replacement': 587250,
#  'replacement speaker': 1136582,
#  'speaker opps': 1279953,
#  'opps thing': 932918,
#  'thing speaker': 1371392,
#  'played nicely': 1003173,
#  'nicely 30': 900219,
#  'seconds went': 1196282,
#  'went dead': 1506860,
#  'dead speaker': 361374,
#  'speaker sounded': 1280174,
#  'sounded good': 1274709,
#  'good brief': 581728,
#  'brief time': 189304,
#  'time played': 1384071,
#  'played emailed': 1003066,
#  'emailed amazon': 453495,
#  'amazon com': 91668,
#  'com wanted': 282187,
#  'wanted role': 1490707,
#  'role dice': 1161976,
#  'dice 3rd': 386002,
#  '3rd try': 32101,
#  'try amazon': 1413814,
#  'amazon responded': 92498,
#  'responded saying': 1144292,
#  'saying problem': 1184095,
#  'problem speaker': 1049632,
#  'speaker widespread': 1280328,
#  'widespread originally': 1511652,
#  'originally thought': 939522,
#  'thought able': 1376078,
#  'able send': 56244,
#  'send additional': 1201792,
#  'additional refunded': 71375,
#  'refunded money': 1122790,
#  'money gave': 860909,
#  'gave 10': 565917,
#  '10 credit': 1873,
#  'credit account': 343822,
#  'account hassle': 61415,
#  'hassle surprised': 613429,
#  'surprised speaker': 1340166,
#  'speaker sale': 1280120,
#  'sale site': 1177060,
#  'site weeks': 1241740,
#  'weeks later': 1504582,
#  'later especially': 740537,
#  'especially manunfacturing': 467751,
#  'manunfacturing defect': 822498,
#  'defect speaker': 367383,
#  'speaker goes': 1279712,
#  'goes dead': 578332,
#  'dead know': 361240,
#  'know issue': 728004,
#  'issue speaker': 701674,
#  'speaker try': 1280270,
#  'try really': 1414654,
#  'really did': 1103561,
#  'did like': 387040,
#  'like product': 767653,
#  'product work': 1056267,
#  'work ve': 1527868,
#  've searched': 1469127,
#  'searched customer': 1193540,
#  'customer reviews': 349750,
#  'reviews problem': 1153607,
#  'problem isolated': 1048780,
#  'isolated order': 700287,
#  'order product': 936495,
#  'product save': 1055746,
#  'save box': 1180310,
#  'box packaging': 183496,
#  'packaging returning': 951431,
#  'returning 30': 1149651,
#  'seconds like': 1195990,
#  'like solid': 768269,
#  'solid product': 1264769,
#  'product low': 1055154,
#  'low price': 804432,
#  'price 32': 1038492,
#  '32 00': 27586,
#  '00 surprised': 355,
#  'surprised failed': 1339940,
#  'failed work': 496156,
#  'work leave': 1526560,
#  'leave feedback': 745078,
#  'feedback like': 509973,
#  'like order': 767329,
#  'order anothrer': 935960,
#  'anothrer hastle': 98234,
#  'hastle returning': 613555,
#  'returning defective': 1149700,
#  'defective products': 367590,
#  'products pain': 1057169,
#  'pain matter': 954998,
#  'matter easy': 827336,
#  'easy amazon': 443970,
#  'amazon tries': 92748,
#  'tries make': 1407948,
#  'make wanted': 816171,
#  'wanted mention': 1490469,
#  'mention generous': 837237,
#  'generous amazon': 569234,
#  'amazon 10': 91378,
#  'credit troubles': 343908,
#  'troubles speaker': 1411319,
#  'speaker amazon': 1279343,
#  'com reputable': 282051,
#  'reputable company': 1138760,
#  'company recommend': 291831,
#  'recommend strongly': 1115400,
#  'strongly continue': 1319042,
#  'continue buy': 321004,
#  'buy prodcuts': 206196,
#  'prodcuts future': 1052974,
#  'future best': 560527,
#  'best luck': 156872,
#  'plastic': 999544,
#  'love': 801926,
#  'far': 501127,
#  'quite': 1085088,
#  'happy': 609374,
#  'fixed': 530475,
#  'brings': 190834,
#  'photographic': 984517,
#  'roots': 1164560,
#  'vendor': 1470372,
#  'awsome': 130024,
#  'quicker': 1083103,
#  'expected': 479480,
#  'business': 201854,
#  'lens great': 750905,
#  'great money': 593223,
#  'money plastic': 861291,
#  'plastic body': 999658,
#  'body lens': 173792,
#  'lens canon': 749957,
#  'canon quality': 224697,
#  'quality love': 1079863,
#  'love far': 802325,
#  'far quite': 502131,
#  'quite happy': 1085524,
#  'happy lens': 609815,
#  'lens using': 752869,
#  'using fixed': 1459235,
#  'fixed lens': 530656,
#  'lens brings': 749905,
#  'brings photographic': 190934,
#  'photographic roots': 984581,
#  'roots vendor': 1164563,
#  'vendor awsome': 1470387,
#  'awsome got': 130038,
#  'got lens': 586730,
#  'lens quicker': 751978,
#  'quicker expected': 1083135,
#  'expected easy': 479718,
#  'easy business': 444057,
#  'gym': 600808,
#  'listing': 777873,
#  'book': 175264,
#  'lying': 807647,
#  'pillow': 993858,
#  'library': 758593,
#  'sure': 1336528,
#  'noise': 903940,
#  'cancelling': 223222,
#  'didn': 387915,
#  'want': 1487752,
#  'spend': 1286543,
#  'pair': 955667,
#  'taking': 1351024,
#  'nice': 898331,
#  'large': 737346,
#  'overheat': 946223,
#  'block': 170033,
#  'external': 487496,
#  'sounds': 1275152,
#  'songs': 1267556,
#  'fold': 541888,
#  'fit': 527555,
#  'easily': 442375,
#  'extercise': 487388,
#  'pockets': 1014000,
#  'appear': 103914,
#  'high': 633160,
#  'audio': 120154,
#  'expert': 483789,
#  'satisfied': 1179391,
#  'produce': 1053000,
#  'reason': 1105522,
#  'stars': 1297081,
#  'modulator': 859094,
#  'cord': 328831,
#  'makes': 816444,
#  'opinion': 931960,
#  'work great': 1526269,
#  'great gym': 592696,
#  'gym listing': 600895,
#  'listing book': 777886,
#  'book lying': 175480,
#  'lying pillow': 807690,
#  'pillow library': 993876,
#  'library sure': 758781,
#  'sure noise': 1337491,
#  'noise cancelling': 904102,
#  'cancelling headphones': 223280,
#  'headphones better': 620943,
#  'better didn': 158634,
#  'didn want': 388847,
#  'want spend': 1489507,
#  'spend pair': 1286804,
#  'pair taking': 956646,
#  'taking gym': 1351259,
#  'gym time': 600979,
#  'time nice': 1383865,
#  'nice large': 899248,
#  'large like': 737923,
#  'like headphones': 766385,
#  'headphones don': 621290,
#  'don make': 416427,
#  'make ears': 815022,
#  'ears overheat': 440881,
#  'overheat like': 946236,
#  'like large': 766762,
#  'large pair': 738075,
#  'pair sound': 956598,
#  'sound block': 1272202,
#  'block external': 170100,
#  'external sounds': 487749,
#  'sounds songs': 1275582,
#  'songs gym': 1267741,
#  'gym fold': 600868,
#  'fold fit': 541952,
#  'fit easily': 527984,
#  'easily extercise': 442835,
#  'extercise pant': 487389,
#  ...}

# %% [markdown]
# ## Question 4: Polarity analysis
#
# Let's derive some insight from our analysis. We want to determine the most polarizing words in the corpus of reviews. In other words, we want identify words that strongly signal a review is either positive or negative. For example, we understand a word like "terrible" will mostly appear in negative rather than positive reviews. The naive Bayes model calculates probabilities such as $P(\text{terrible } | \text{ negative})$, the probability the word "terrible" appears in the text, given that the review is negative. Using these probabilities, we can derive a **polarity score** for each counted word,
#
# $$
# \text{polarity} =  \log\left(\frac{P(\text{word } | \text{ positive})}{P(\text{word } | \text{ negative})}\right).
# $$
#
# The polarity analysis is an example where a simpler model offers more explicability than a more complicated model. For this question, you are asked to determine the top twenty-five words with the largest positive **and** largest negative polarity, for a total of fifty words. For this analysis, you should:
#
# 1. Use the naive Bayes model, `MultinomialNB`.
# 1. Use tf-idf weighting.
# 1. Remove stop words.
#
# A trained naive Bayes model stores the log of the probabilities in the attribute `feature_log_prob_`. It is a NumPy array of shape (number of classes, the number of features). You will need the mapping between feature index to word. For this problem, you will use a different data set; it has been processed to only include reviews with one and five stars. You can download it below.

# %%
# %%bash
# wget http://dataincubator-wqu.s3.amazonaws.com/mldata/amazon_one_and_five_star_reviews.json.gz -nc -P ./data
# Out:
# --2021-08-13 11:26:21--  http://dataincubator-wqu.s3.amazonaws.com/mldata/amazon_one_and_five_star_reviews.json.gz
# Resolving dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)... 52.217.43.76
# Connecting to dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)|52.217.43.76|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2970853 (2.8M) [application/x-gzip]
# Saving to: ‘./data/amazon_one_and_five_star_reviews.json.gz’
#
#      0K .......... .......... .......... .......... ..........  1% 3.24M 1s
#     50K .......... .......... .......... .......... ..........  3% 6.63M 1s
#    100K .......... .......... .......... .......... ..........  5% 6.98M 1s
#    150K .......... .......... .......... .......... ..........  6% 46.9M 0s
#    200K .......... .......... .......... .......... ..........  8% 62.2M 0s
#    250K .......... .......... .......... .......... .......... 10% 47.5M 0s
#    300K .......... .......... .......... .......... .......... 12% 8.73M 0s
#    350K .......... .......... .......... .......... .......... 13% 45.6M 0s
#    400K .......... .......... .......... .......... .......... 15% 51.9M 0s
#    450K .......... .......... .......... .......... .......... 17%  108M 0s
#    500K .......... .......... .......... .......... .......... 18%  237M 0s
#    550K .......... .......... .......... .......... .......... 20%  227M 0s
#    600K .......... .......... .......... .......... .......... 22% 8.41M 0s
#    650K .......... .......... .......... .......... .......... 24% 47.6M 0s
#    700K .......... .......... .......... .......... .......... 25% 54.2M 0s
#    750K .......... .......... .......... .......... .......... 27% 13.9M 0s
#    800K .......... .......... .......... .......... .......... 29%  124M 0s
#    850K .......... .......... .......... .......... .......... 31%  277M 0s
#    900K .......... .......... .......... .......... .......... 32%  150M 0s
#    950K .......... .......... .......... .......... .......... 34%  120M 0s
#   1000K .......... .......... .......... .......... .......... 36%  173M 0s
#   1050K .......... .......... .......... .......... .......... 37%  139M 0s
#   1100K .......... .......... .......... .......... .......... 39%  196M 0s
#   1150K .......... .......... .......... .......... .......... 41%  211M 0s
#   1200K .......... .......... .......... .......... .......... 43%  244M 0s
#   1250K .......... .......... .......... .......... .......... 44%  348M 0s
#   1300K .......... .......... .......... .......... .......... 46% 10.2M 0s
#   1350K .......... .......... .......... .......... .......... 48% 24.7M 0s
#   1400K .......... .......... .......... .......... .......... 49% 13.8M 0s
#   1450K .......... .......... .......... .......... .......... 51% 58.6M 0s
#   1500K .......... .......... .......... .......... .......... 53% 74.9M 0s
#   1550K .......... .......... .......... .......... .......... 55% 57.8M 0s
#   1600K .......... .......... .......... .......... .......... 56% 17.1M 0s
#   1650K .......... .......... .......... .......... .......... 58% 74.0M 0s
#   1700K .......... .......... .......... .......... .......... 60% 75.1M 0s
#   1750K .......... .......... .......... .......... .......... 62% 16.7M 0s
#   1800K .......... .......... .......... .......... .......... 63% 66.2M 0s
#   1850K .......... .......... .......... .......... .......... 65% 80.2M 0s
#   1900K .......... .......... .......... .......... .......... 67% 18.4M 0s
#   1950K .......... .......... .......... .......... .......... 68% 67.7M 0s
#   2000K .......... .......... .......... .......... .......... 70% 86.3M 0s
#   2050K .......... .......... .......... .......... .......... 72% 19.5M 0s
#   2100K .......... .......... .......... .......... .......... 74%  348M 0s
#   2150K .......... .......... .......... .......... .......... 75%  318M 0s
#   2200K .......... .......... .......... .......... .......... 77%  382M 0s
#   2250K .......... .......... .......... .......... .......... 79%  120M 0s
#   2300K .......... .......... .......... .......... .......... 81% 87.8M 0s
#   2350K .......... .......... .......... .......... .......... 82% 14.0M 0s
#   2400K .......... .......... .......... .......... .......... 84% 69.2M 0s
#   2450K .......... .......... .......... .......... .......... 86% 80.6M 0s
#   2500K .......... .......... .......... .......... .......... 87%  183M 0s
#   2550K .......... .......... .......... .......... .......... 89%  271M 0s
#   2600K .......... .......... .......... .......... .......... 91%  261M 0s
#   2650K .......... .......... .......... .......... .......... 93%  338M 0s
#   2700K .......... .......... .......... .......... .......... 94%  300M 0s
#   2750K .......... .......... .......... .......... .......... 96%  304M 0s
#   2800K .......... .......... .......... .......... .......... 98%  376M 0s
#   2850K .......... .......... .......... .......... .......... 99%  311M 0s
#   2900K .                                                     100% 2334G=0.09s
#
# 2021-08-13 11:26:21 (31.5 MB/s) - ‘./data/amazon_one_and_five_star_reviews.json.gz’ saved [2970853/2970853]

# %% [markdown]
# In order to avoid memory issues, let's delete the older data.

# %%
del data, ratings

# %%
import numpy as np
import gzip
import simplejson as json

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer

with gzip.open("data/amazon_one_and_five_star_reviews.json.gz", "r") as f:
    data_polarity = [json.loads(line) for line in f]

ratings = [x['overall'] for x in data_polarity]

# %%
data_polarity[:3]
# Out:
# [{'reviewerID': 'A31RSJTGLVV3TR',
#   'asin': 'B000093UDP',
#   'reviewerName': 'T. Wayne',
#   'helpful': [11, 12],
#   'reviewText': "This worked perfectly for about 8 rewinds.  But once it eats one of your precious tapes you'll probably be as dissapointed as I was.  Buyer beware... these rewinders are mostly the same look; but marketed by different companies.  They all eat tape.",
#   'overall': 1.0,
#   'summary': "It's a super tape-eater",
#   'unixReviewTime': 1210550400,
#   'reviewTime': '05 12, 2008'},
#  {'reviewerID': 'A2Y739CRM15WDL',
#   'asin': 'B00005MNSR',
#   'reviewerName': 'Sires "I like mysteries (particularly British...',
#   'helpful': [0, 0],
#   'reviewText': "This was a choice in my gold box or I might not have bought it. I would have been missing out on a very good monitor if I hadn't.I just bought a new 2.53 gigahertz multi media computer running XP home edition and wanted a monitor with a small footprint but still able to handle graphics intense functions.  Set up was a breeze.  I just plugged it in and it was recognized at once.  While I normally use a 17 inch monitor, I have to say that this 15 inch LCD monitor was easier to read, especially at a distance.I am definitely pleased with this product.",
#   'overall': 5.0,
#   'summary': 'Well worth the Money',
#   'unixReviewTime': 1039996800,
#   'reviewTime': '12 16, 2002'},
#  {'reviewerID': 'A3QEVOBJU39GV5',
#   'asin': 'B00004Z0C7',
#   'reviewerName': 'Marilyn H LONGVIEW WA "angellover"',
#   'helpful': [0, 2],
#   'reviewText': "I FEEL THE ABOVE TOPIC SAY'S IT ALL.. SORRY FOR HOW LATE THIS IS BUT, I FIND MY SELF VERY BUSY WITH BOOMING HOME BUSINESS",
#   'overall': 1.0,
#   'summary': 'THEY STINK',
#   'unixReviewTime': 1394928000,
#   'reviewTime': '03 16, 2014'}]

# %%
pipe = Pipeline([
    ("seector", KeySelector('reviewText')),
    ('vectorizer',TfidfVectorizer(stop_words = 'english')),
    ('classifier', MultinomialNB())
])
pipe.fit(data_polarity, ratings)
# Out:
# Pipeline(steps=[('seector', KeySelector(key='reviewText')),
#                 ('vectorizer', TfidfVectorizer(stop_words='english')),
#                 ('classifier', MultinomialNB())])

# %%
pipe.predict(data_polarity)[:10]
# Out:
# array([1., 5., 1., 5., 5., 5., 1., 5., 5., 5.])

# %%
nb = pipe.named_steps['classifier']

# %%
nb.classes_
# Out:
# array([1., 5.])

# %%
nb.feature_log_prob_.shape
# Out:
# (2, 25411)

# %%
words = pipe.named_steps['vectorizer'].get_feature_names()

# %%
words[10000]
# Out:
# 'frequent'

# %%
log_prob = nb.feature_log_prob_

# %%
polarity = log_prob[0] - log_prob[1]

# %%
polarity
# Out:
# array([ 0.70107467, -0.32918854, -0.29068542, ...,  0.61837882,
#         0.10651328,  0.19406434])

# %%
indices = np.argsort(polarity)

# %%
indices_top = np.hstack([indices[:25], indices[-25:]])

# %%
indices_top
# Out:
# array([11275,  3609, 17631, 16544, 14775, 17108,  2511, 21599, 13906,
#        11965,  8872,  4034, 16902,   524,  5008, 10935,  3302, 17109,
#         7955,  6371, 16703, 22319,  4351,  9259,  8191, 18496, 22622,
#         7410, 21414, 18037, 23695, 11446,  3303, 23403, 17067,  3775,
#         6871, 23059, 25037, 25043, 23889, 10263, 19011, 22395, 12793,
#        25041, 19012, 19009, 24520, 18484])

# %%
len(indices_top)
# Out:
# 50

# %%
[words[i] for i in indices_top]
# Out:
# ['highly',
#  'beat',
#  'protects',
#  'perfect',
#  'monopod',
#  'portrait',
#  'amazing',
#  'sturdy',
#  'macro',
#  'incredible',
#  'excellent',
#  'bokeh',
#  'pleased',
#  '200mm',
#  'charm',
#  'handy',
#  'awesome',
#  'portraits',
#  'dslr',
#  'crisp',
#  'photography',
#  'telephoto',
#  'buck',
#  'fantastic',
#  'easy',
#  'refused',
#  'threw',
#  'disappointing',
#  'stopped',
#  'randomly',
#  'unreliable',
#  'horrible',
#  'awful',
#  'unacceptable',
#  'poor',
#  'beware',
#  'defective',
#  'trash',
#  'worse',
#  'worthless',
#  'useless',
#  'garbage',
#  'returned',
#  'terrible',
#  'junk',
#  'worst',
#  'returning',
#  'return',
#  'waste',
#  'refund']

# %%
top_50 = [words[i] for i in indices_top]

# %%
grader.score.nlp__most_polar(top_50)
# Out:
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# *Copyright &copy; 2021 WorldQuant University. This content is licensed solely for personal use. Redistribution or publication of this material is strictly prohibited.*
